# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests

# %%
pip install lxml
# Out:
# Requirement already satisfied: lxml in /home/leonardo/anaconda3/lib/python3.11/site-packages (4.9.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
url = 'https://pt.wikipedia.org/wiki/Estados_da_Alemanha'

# %%
response = requests.get(url)
response
# Out:
# <Response [200]>

# %%
html = response.text

# %%
soup = BeautifulSoup(html, 'html.parser')

# %%
germany_table = soup.find('table',{'class':"wikitable"})

# %%
df = pd.read_html(str(germany_table))

# convert list to dataframe
df = pd.DataFrame(df[0])
print(df.head())
# Out:
# /tmp/ipykernel_6703/3341287661.py:1: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(germany_table))
#    Brasão de armas                                       Estado  \
# 0              NaN         Bade-Vurtemberga (Baden-Württemberg)
# 1              NaN                Baixa Saxônia (Niedersachsen)
# 2              NaN  Baviera, Estado Livre da (Freistaat Bayern)
# 3              NaN                              Berlim (Berlin)
# 4              NaN                   Brandemburgo (Brandenburg)
#
#    Parte da RFA desde                             Chefe de governo  \
# 0                1949  Winfried Kretschmann (Aliança 90/Os Verdes)
# 1                1949                           Stephan Weil (SPD)
# 2                1949                           Markus Söder (CSU)
# 3                1990                         Michael Müller (SPD)
# 4                1990                         Dietmar Woidke (SPD)
#
#    Fotografia Área (km²)   População Hab. por km²                Capital Sigla
# 0         NaN     35 752  10 755 000          301  Estugarda (Stuttgart)    BW
# 1         NaN     47 609   7 914 000          166     Hanôver (Hannover)    NI
# 2         NaN     70 552  12 542 000          178      Munique (München)    BY
# 3         NaN        892   3 469 000        3 890                nenhuma    BE
# 4         NaN     29 479   2 500 000           85                Potsdam    BB

# %%
df
# Out:
#     Brasão de armas                                             Estado  \
# 0               NaN               Bade-Vurtemberga (Baden-Württemberg)
# 1               NaN                      Baixa Saxônia (Niedersachsen)
# 2               NaN        Baviera, Estado Livre da (Freistaat Bayern)
# 3               NaN                                    Berlim (Berlin)
# 4               NaN                         Brandemburgo (Brandenburg)
# 5               NaN  Bremen, Cidade Hanseática Livre de (Freie Hans...
# 6               NaN  Hamburgo, Cidade Livre e Hanseática de (Freie ...
# 7               NaN                                     Hesse (Hessen)
# 8               NaN  Meclemburgo-Pomerânia Ocidental (Mecklenburg-V...
# 9               NaN   Renânia do Norte-Vestfália (Nordrhein-Westfalen)
# 10              NaN               Renânia-Palatinado (Rheinland-Pfalz)
# 11              NaN                                   Sarre (Saarland)
# 12              NaN       Saxônia, Estado Livre da (Freistaat Sachsen)
# 13              NaN                    Saxônia-Anhalt (Sachsen-Anhalt)
# 14              NaN            Eslésvico-Holsácia (Schleswig-Holstein)
# 15              NaN    Turíngia, Estado Livre da (Freistaat Thüringen)
#
#     Parte da RFA desde                             Chefe de governo  \
# 0                 1949  Winfried Kretschmann (Aliança 90/Os Verdes)
# 1                 1949                           Stephan Weil (SPD)
# 2                 1949                           Markus Söder (CSU)
# 3                 1990                         Michael Müller (SPD)
# 4                 1990                         Dietmar Woidke (SPD)
# 5                 1949                   Andreas Bovenschulte (SPD)
# 6                 1949                     Peter Tschentscher (SPD)
# 7                 1949                        Volker Bouffier (CDU)
# 8                 1990                       Manuela Schwesig (SPD)
# 9                 1949                          Armin Laschet (CDU)
# 10                1949                            Malu Dreyer (SPD)
# 11                1957                            Tobias Hans (CDU)
# 12                1990                     Michael Kretschmer (CDU)
# 13                1990                        Reiner Haseloff (CDU)
# 14                1949                         Daniel Günther (CDU)
# 15                1990                    Bodo Ramelow (A Esquerda)
#
#     Fotografia Área (km²)   População Hab. por km²                    Capital  \
# 0          NaN     35 752  10 755 000          301      Estugarda (Stuttgart)
# 1          NaN     47 609   7 914 000          166         Hanôver (Hannover)
# 2          NaN     70 552  12 542 000          178          Munique (München)
# 3          NaN        892   3 469 000        3 890                    nenhuma
# 4          NaN     29 479   2 500 000           85                    Potsdam
# 5          NaN        419     661 000        1 577                    nenhuma
# 6          NaN        755   1 788 000        2 368                    nenhuma
# 7          NaN     21 115   6 066 000          287                  Wiesbaden
# 8          NaN     23 180   1 639 000           71                   Schwerin
# 9          NaN     34 085  17 837 000          523  Dusseldórfia (Düsseldorf)
# 10         NaN     19 853   3 999 000          202           Mogúncia (Mainz)
# 11         NaN      2 569   1 018 000          400    Sarbruque (Saarbrücken)
# 12         NaN     18 416   4 143 000          227           Dresda (Dresden)
# 13         NaN     20 446   2 331 000          116     Magdeburgo (Magdeburg)
# 14         NaN     15 799   2 833 000          179                       Kiel
# 15         NaN     16 172   2 231 000          138                     Erfurt
#
#    Sigla
# 0     BW
# 1     NI
# 2     BY
# 3     BE
# 4     BB
# 5     HB
# 6     HH
# 7     HE
# 8     MV
# 9     NW
# 10    RP
# 11    SL
# 12    SN
# 13    ST
# 14    SH
# 15    TH
